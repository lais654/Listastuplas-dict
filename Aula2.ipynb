# %% [markdown]
# <a href="https://colab.research.google.com/github/lais654/Listastuplas-dict/blob/main/Aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Atividade 1

# %%
materias = ["história", "filosofia", "sociologia"]
notas = [8.5, 9.0, 7.8]
aluno = {"nome": "Mateus Pereira", "idade": 18, "curso": "ciência da computação"}

print ("materias:", materias)
print ("notas:", notas)
print ("informações do aluno:", aluno)
# Out:
# materias: ['história', 'filosofia', 'sociologia']
# notas: [8.5, 9.0, 7.8]
# informações do aluno: {'nome': 'Mateus Pereira', 'idade': 18, 'curso': 'ciência da computação'}

# %% [markdown]
# Atividade 2

# %%
acessorios = ["motor", "bateria", "porta luvas"]
especificacoes = (20, 50)

carro = {
    "marca": 'fiat',"modelo": 'uno', "ano": "2006"
    }


print ("acessorios:", acessorios)
print ("especificacoes:", especificacoes)
print ("carro:", carro)
# Out:
# acessorios: ['motor', 'bateria', 'porta luvas']
# especificacoes: (20, 50)
# carro: {'marca': 'fiat', 'modelo': 'uno', 'ano': '2006'}
