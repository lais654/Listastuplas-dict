# %% [markdown]
# <a href="https://colab.research.google.com/github/lais654/Listastuplas-dict/blob/main/Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Atividade 1

# %%
nome = "joao silva"
idade = 25
profissao = "desenvolvedor"

print ("nome:",nome)
print ("idade:",idade)
print ("profissao:",profissao)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26657/3704395078.py in <cell line: 0>()
#       3 profissao = "desenvolvedor"
#       4
# ----> 5 print ("nome:",nome)
#       6 print ("idade:",idade)
#       7 print ("profissao:",profissao)
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# Atividade 2

# %%
produto = "notebook"
marca = "Dell"
preco = 4500

print ("produto:",produto)
print ("marca:",marca)
print (f"preço R${preco:.2f}")

# %% [markdown]
# Atividade 3

# %%
num1 = 12
num2 = 6
soma = (num1 + num2)
sub = (num1 - num2)
mult = (num1 * num2)
div = int(num1 /num2)

print ("Numero 1:", num1)
print ("Numero 2:", num2)

print ("Soma:", soma)
print ("subtracão:", sub)
print ("multiplicacao:", mult)
print ("divisao", div)

# %% [markdown]
# Atividade 4

# %%
num1 = 7
num2 = 2
soma = num1 + num2
sub = num1 - num2
mult = num1 * num2
div = num1 / num2
pot = num1 ** num2
print("soma: ",soma)
print("subtracao: ",sub)
print("multiplicacao: ",mult)
print("divisao: ",div)
print("pot", pot)
# Out:
# soma:  9
# subtracao:  5
# multiplicacao:  14
# divisao:  3.5
# pot 49
